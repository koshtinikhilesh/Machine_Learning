# %%
# Titanic Datasets
# Python imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reading the datasets
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# The training datasets contain 11 features and 1 survived class. Also it contain total 891 value including the some null values.In addition, there are 2 float values, 5 integer value and 5 categorical objects in the training datasets.

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# let check the null values
# 38% survived in titanic.
total = train_df.isnull().sum().sort_values(ascending=False)
print total.head()
# Out:
# Cabin       687
# Age         177
# Embarked      2
# Fare          0
# Ticket        0
# dtype: int64

# %%
len(train_df)
# Out:
# 891

# %%
percent1 = train_df.isnull().sum()/len(train_df) * 100

# %%
percent1.head()
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# dtype: float64

# %%
missing_data = pd.concat([total,percent1], axis=1,keys=['Total','%'], sort=False)

# %%
missing_data.head()
# Out:
#           Total          %
# Cabin       687  77.104377
# Age         177  19.865320
# Embarked      2   0.224467
# Fare          0   0.000000
# Ticket        0   0.000000

# %% [markdown]
# The Embarked feature had only 2 missing values in comparison with Age 177 values and Cabin 687 values.
# 'Cabin' feature have 77% missing data.

# %%
# column values
train_df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %% [markdown]
# The above all feature will contribute to the survival features. But the PassengerId and Name and Ticket will not contribute more in the training. As a result, we will drop these features.

# %%
# drop the passengerID
train_df.drop(['PassengerId'], axis=1,inplace=True)
test_df.drop(['PassengerId'], axis=1)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                                   Kelly, Mr. James    male  34.5
# 1         3                   Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                          Myles, Mr. Thomas Francis    male  62.0
# 3         3                                   Wirz, Mr. Albert    male  27.0
# 4         3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5         3                         Svensson, Mr. Johan Cervin    male  14.0
# 6         3                               Connolly, Miss. Kate  female  30.0
# 7         2                       Caldwell, Mr. Albert Francis    male  26.0
# 8         3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# 9         3                            Davies, Mr. John Samuel    male  21.0
# 10        3                                   Ilieff, Mr. Ylio    male   NaN
# ...

# %%
train_df.columns.values
# Out:
# array(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
train_df[["Cabin","Survived"]].head()
# Out:
#   Cabin  Survived
# 0   NaN         0
# 1   C85         1
# 2   NaN         1
# 3  C123         1
# 4   NaN         0

# %%
# import re
# deck = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6, "G": 7, "U": 8}
# data = [train_df, test_df]

# for dataset in data:
#     dataset['Cabin'] = dataset['Cabin'].fillna("U0")
#     dataset['Deck'] = dataset['Cabin'].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
#     dataset['Deck'] = dataset['Deck'].map(deck)
#     dataset['Deck'] = dataset['Deck'].fillna(0)
#     dataset['Deck'] = dataset['Deck'].astype(int)

# %%
import re
deck = {'A':1,'B':2,'C':3,'D':4,'E':5,'F':6,'G':7,'U':8}
data = [train_df,test_df]
for value  in data:
    value["Cabin"] = value["Cabin"].fillna('U0')
    value["Deck"] = value["Cabin"].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
    value["Deck"] = value["Deck"].map(deck)
    value["Deck"] = value["Deck"].fillna(0)
    value["Deck"] = value["Deck"].astype('int')
    #print value
    #value["Cabin"]

# %%
value.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Deck
# 0  34.5      0      0   330911   7.8292    U0        Q     8
# 1  47.0      1      0   363272   7.0000    U0        S     8
# 2  62.0      0      0   240276   9.6875    U0        Q     8
# 3  27.0      0      0   315154   8.6625    U0        S     8
# 4  22.0      1      1  3101298  12.2875    U0        S     8

# %%
# check the null values
total = train_df.isnull().sum().sort_values(ascending=False)

# %%
total
# Out:
# Age         177
# Embarked      2
# Deck          0
# Cabin         0
# Fare          0
# Ticket        0
# Parch         0
# SibSp         0
# Sex           0
# Name          0
# Pclass        0
# Survived      0
# dtype: int64

# %% [markdown]
# Cabin have 0 null values. Let edit Embarked features

# %%
# drop the Cabin values
train_df.drop(['Cabin'], axis=1,inplace=True)
test_df.drop(['Cabin'], axis=1,inplace=True)

# %%
train_df.columns.values
# Out:
# array(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'Deck'], dtype=object)

# %% [markdown]
# Let remove the AGE features null values

# %%
# data = [train_df, test_df]

# for dataset in data:
#     mean = train_df["Age"].mean()
#     std = test_df["Age"].std()
#     is_null = dataset["Age"].isnull().sum()
#     # compute random numbers between the mean, std and is_null
#     rand_age = np.random.randint(mean - std, mean + std, size = is_null)
#     # fill NaN values in Age column with random values generated
#     age_slice = dataset["Age"].copy()
#     age_slice[np.isnan(age_slice)] = rand_age
#     dataset["Age"] = age_slice
#     dataset["Age"] = train_df["Age"].astype(int)

# %%
data = [train_df, test_df]
for value in data:
    mean = value["Age"].mean()
    std = value["Age"].std()
    is_null = value["Age"].isnull().sum()
    print 'Mean:-- {}, STD:-- {}, NULL:-- {}'.format(mean,std,is_null)
    # compute the random values
    rand_age = np.random.randint(mean-std,mean + std,size=is_null)
    # print rand_age
    # fill the null values
    age_slice = value["Age"].copy()
    #print age_slice
    age_slice[np.isnan(age_slice)] = rand_age
    #print age_slice
    value["Age"] = age_slice
    value["Age"] = value["Age"].astype(int)
# Out:
# Mean:-- 29.6991176471, STD:-- 14.5264973323, NULL:-- 177
# Mean:-- 30.2725903614, STD:-- 14.1812092356, NULL:-- 86

# %%
train_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex  Age  SibSp  Parch            Ticket     Fare Embarked  Deck
# 0    male   22      1      0         A/5 21171   7.2500        S     8
# 1  female   38      1      0          PC 17599  71.2833        C     3
# 2  female   26      0      0  STON/O2. 3101282   7.9250        S     8
# 3  female   35      1      0            113803  53.1000        S     3
# 4    male   35      0      0            373450   8.0500        S     8

# %%
# Now the number of null values are:--
train_df.isnull().sum().sort_values(ascending=False)
# Out:
# Embarked    2
# Deck        0
# Fare        0
# Ticket      0
# Parch       0
# SibSp       0
# Age         0
# Sex         0
# Name        0
# Pclass      0
# Survived    0
# dtype: int64

# %% [markdown]
# Only Embarked feature have null values in the datasets

# %%
train_df["Embarked"].head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %%
train_df["Embarked"].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
# replace the null value with the common value 'S'
data = [train_df, test_df]
for value in data:
    value["Embarked"] = value["Embarked"].fillna('S')

# %%
train_df.isnull().sum().sort_values(ascending=False)
# Out:
# Deck        0
# Embarked    0
# Fare        0
# Ticket      0
# Parch       0
# SibSp       0
# Age         0
# Sex         0
# Name        0
# Pclass      0
# Survived    0
# dtype: int64

# %% [markdown]
# Hence all the null values are converted into non-null values.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         891 non-null int64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null object
# Deck        891 non-null int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 76.6+ KB

# %% [markdown]
# Still there are float, int and object features.

# %%
train_df["Fare"].head(10)
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# 6    51.8625
# 7    21.0750
# 8    11.1333
# 9    30.0708
# Name: Fare, dtype: float64

# %%
data = [train_df, test_df]
for value in data:
    value['Fare'] = value['Fare'].fillna(value["Fare"].median())
    value['Fare'] = value['Fare'].astype(int)

# %% [markdown]
# Remaining are the categorical feature:- Name, Ticket, Embarked, and Sex

# %% [markdown]
# Changing the Sex Feature

# %%
train_df["Sex"].head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
gender = {'male':0, 'female':1}
data = [train_df, test_df]
for value in data:
    value["Sex"] = value["Sex"].map(gender)

# %%
train_df.head(10)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
# 5         0       3                                   Moran, Mr. James    0
# 6         0       1                            McCarthy, Mr. Timothy J    0
# 7         0       3                     Palsson, Master. Gosta Leonard    0
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)    1
#
#    Age  SibSp  Parch            Ticket  Fare Embarked  Deck
# 0   22      1      0         A/5 21171     7        S     8
# ...

# %% [markdown]
# Changing the Name Feature

# %%
# dropping the Name features
train_df.drop(['Name'],inplace=True, axis=1)
test_df.drop(['Name'],inplace=True, axis=1)

# %%
train_df.columns.values
# Out:
# array(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked', 'Deck'], dtype=object)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int64
# Age         891 non-null int64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null int64
# Embarked    891 non-null object
# Deck        891 non-null int64
# dtypes: int64(8), object(2)
# memory usage: 69.7+ KB

# %%
train_df["Embarked"].head()
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %%
values = {'S':0,'C':1,'Q':2}
data = [train_df,test_df]
for value in data:
    value["Embarked"] = value["Embarked"].map(values)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int64
# Age         891 non-null int64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null int64
# Embarked    891 non-null int64
# Deck        891 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 69.7+ KB

# %%
train_df["Ticket"].describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# Name: Ticket, dtype: object

# %% [markdown]
# IT has 682 unique values, So we will drop the Ticket features

# %%
train_df.drop(['Ticket'],axis=1,inplace=True)
test_df.drop(['Ticket'],axis=1,inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int64
# Age         891 non-null int64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null int64
# Embarked    891 non-null int64
# Deck        891 non-null int64
# dtypes: int64(9)
# memory usage: 62.7 KB

# %%
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked  Deck
# 0         0       3    0   22      1      0     7         0     8
# 1         1       1    1   38      1      0    71         1     3
# 2         1       3    1   26      0      0     7         0     8
# 3         1       1    1   35      1      0    53         0     3
# 4         0       3    0   35      0      0     8         0     8

# %%
# Training the data into models
Y_train = train_df["Survived"]
X_train = train_df.drop(["Survived"], axis=1)
X_test.head()
# Out:
#    Pclass  Sex  Age  SibSp  Parch  Fare  Embarked  Deck
# 0       3    0   34      0      0     7         2     8
# 1       3    1   47      1      0     7         0     8
# 2       2    0   62      0      0     9         2     8
# 3       3    0   27      0      0     8         0     8
# 4       3    1   22      1      1    12         0     8

# %%
test_df.columns.values
# Out:
# array(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'Deck'], dtype=object)

# %%
# Python imports from sklearn
from sklearn import linear_model
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import  GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier

# %%
# Random Forest
regressor = RandomForestClassifier(n_estimators=30, random_state = 0)
regressor.fit(X_train, Y_train)
X_test = X_test.drop(["Ticket"], axis=1).copy()
X_test.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-661-ef9e9d7d9c9c> in <module>()
#       2 regressor = RandomForestClassifier(n_estimators=30, random_state = 0)
#       3 regressor.fit(X_train, Y_train)
# ----> 4 X_test = X_test.drop(["Ticket"], axis=1).copy()
#       5 X_test.head()
#
# /home/nikhilesh/jupyter/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
X_train.head()

# %%
y_pred = regressor.predict(X_test)
acc_random_forest = round(regressor.score(X_train, Y_train)*100,2)
random_score

# %%
# Logistic Regression
log_regressor = LogisticRegression()
log_regressor.fit(X_train, Y_train)
y_pred = log_regressor.predict(X_test)

# %%
acc_log_regression = round(log_regressor.score(X_train, Y_train)*100,2)

# %%
# K neighbour Neihgbours
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
y_pred = knn.predict(X_test)

# %%
acc_knn = round(knn.score(X_train, Y_train)*100,2)

# %%
#gaussian Naiove bayes
gaussian =GaussianNB()
gaussian.fit(X_train, Y_train)
y_pred = gaussian.predict(X_test)

# %%
acc_gaussian = round(gaussian.score(X_train, Y_train)*100,2)

# %%
#decisionTree
dtree = DecisionTreeClassifier()
dtree.fit(X_train, Y_train)
dtree.predict(X_test)
acc_dtree = round(dtree.score(X_train, Y_train) * 100,2)

# %% [markdown]
# DECIDE THE BEST MODEL

# %%
final_score = [acc_dtree, acc_gaussian, acc_knn, acc_log_regression, acc_random_forest]

# %%
final_score

# %%
model_name = ['DecisionTree', 'Gaussian','Kneighbors','LogisticRegression','RandomForest']

# %%
model_name

# %%
pd.DataFrame({'Model_Name':model_name,'FInal_score':final_score})

# %% [markdown]
# Random Forest and Decision Tree have higher accuracy

# %%
# confusion matrix
random_forest = RandomForestClassifier(n_estimators=100, random_state =1)
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
predictions = cross_val_predict(random_forest, X_train, Y_train, cv=3)
#print predictions

# %%
confusion_matrix(Y_train,predictions)

# %%
random_forest.fit(X_train, Y_train)
y_predictions = random_forest.predict(X_test)

# %%
random_forest.score(X_train, Y_train)

# %%
submission = pd.DataFrame({
        "PassengerId": test_df["PassengerId"],
        "Survived": y_predictions
    })

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         1
# 4          896         0
